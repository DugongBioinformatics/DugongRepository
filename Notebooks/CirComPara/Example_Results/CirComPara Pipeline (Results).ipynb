# %% [markdown]
# # CirComPara Pipeline

# %% [markdown]
# To demonstrate Dugong ́s effectiveness to distribute and run bioinformatics tools in alternative computational environments, the CirComPara pipeline was implemented in a Dugong container and tested in different OS with the aid of virtual machines (VM) or cloud computing servers.
#
# CirComPara is a computational pipeline to detect, quantify, and correlate expression of linear and circular RNAs from RNA-seq data. Is a highly complex pipeline, which employs a series of bioinformatics software and was originally designed to run in an Ubuntu Server 16.04 LTS (x64).
#
# Although authors provide details regarding the expected versions of each software and their dependency requirements, several problems can still be encountered during CirComPara implementation by inexperienced users.
#
# See documentation for CirComPara installation details: https://github.com/egaffo/CirComPara

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Pipeline steps

# %% [markdown]
# - The test data is already unpacked and available in the path: **/headless/CirComPara/test_circompara/**

# %% [markdown]
# - The **meta.csv** and **vars.py** files are already configured to run CirComPara, as documented: https://github.com/egaffo/CirComPara

# %% [markdown]
# - Defining the folder for the analysis with the CirComPara of the test data provided by the developers of the tool:

# %%
from functools import partial
from os import chdir

chdir('/headless/CirComPara/test_circompara/analysis')

# %% [markdown]
# - Viewing files from /headless/CirComPara/test_circompara/

# %%
from IPython.display import FileLinks, FileLink

FileLinks('/headless/CirComPara/test_circompara/')
# Out:
# /headless/CirComPara/test_circompara/
#   meta_se.csv
#   meta.csv
#   vars.py
# /headless/CirComPara/test_circompara/analysis/
#   .sconsign.dblite
#   meta.csv
#   vars.py
# /headless/CirComPara/test_circompara/annotation/
#   CFLAR_HIPK3.fa.byo_index
#   CFLAR_HIPK3.fa.fai
#   CFLAR_HIPK3.fa
#   CFLAR_HIPK3.gtf
# /headless/CirComPara/test_circompara/reads/
#   readsB_1.fastq.gz
#   readsA_2.fastq.gz
#   readsA_1.fastq.gz
#   readsB_2.fastq.gz

# %% [markdown]
# - Viewing the contents of the configuration file: vars.py

# %%
# !cat /headless/CirComPara/test_circompara/analysis/vars.py
# Out:
# META            = "meta.csv"
# GENOME_FASTA    = '/headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa'
# ANNOTATION      = '/headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf'
# CIRI            = "/headless/CirComPara/bin/CIRI_v2.0.2.pl"
# CPUS            = "3"
# PREPROCESSOR    = "trimmomatic"
# CIRCRNA_METHODS = "ciri,circexplorer,findcirc,testrealign"
# TOGGLE_TRANSCRIPTOME_RECONSTRUCTION = 'False'
# DIFF_EXP = 'False'
# DESEQ = 'False'
# PREPROCESSOR_PARAMS = "MAXINFO:40:0.5 LEADING:20 TRAILING:20 SLIDINGWINDOW:4:30 MINLEN:35 AVGQUAL:30"
# CUFFNORM_EXTRA_PARAMS = "--output-format cuffdiff"
# BWA_PARAMS = "-T 19" ## parameter recomended by CIRI manual

# %% [markdown]
# - Viewing the contents of the configuration file: meta.csv

# %%
# !cat /headless/CirComPara/test_circompara/analysis/meta.csv
# Out:
# file,sample,condition,adapter
# /headless/CirComPara/test_circompara/reads/readsA_1.fastq.gz,sample_A,A,/headless/CirComPara/tools/Trimmomatic-0.36/adapters/TruSeq3-PE-2.fa
# /headless/CirComPara/test_circompara/reads/readsA_2.fastq.gz,sample_A,A,/headless/CirComPara/tools/Trimmomatic-0.36/adapters/TruSeq3-PE-2.fa
# /headless/CirComPara/test_circompara/reads/readsB_1.fastq.gz,sample_B,B,/headless/CirComPara/tools/Trimmomatic-0.36/adapters/TruSeq3-PE-2.fa
# /headless/CirComPara/test_circompara/reads/readsB_2.fastq.gz,sample_B,B,/headless/CirComPara/tools/Trimmomatic-0.36/adapters/TruSeq3-PE-2.fa

# %% [markdown]
# - Running CirCompara with test data

# %%
# !../../circompara
# Out:
# scons: Reading SConscript files ...
# scons: done reading SConscript files.
# scons: Building targets ...
# gtfToGenePred -infoOut=junk2_dbs/genePred.transcripts.info /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf junk2_dbs/CFLAR_HIPK3.genePred
# cut -f9 junk2_dbs/genePred.transcripts.info | grep -v geneName | paste - junk2_dbs/CFLAR_HIPK3.genePred > junk2_dbs/CFLAR_HIPK3.genePred.wgn
# hisat2-build -f --seed 1 -p 3 /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa junk2_dbs/indexes/hisat2/CFLAR_HIPK3
# Settings:
#   Output files: "junk2_dbs/indexes/hisat2/CFLAR_HIPK3.*.ht2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Local offset rate: 3 (one in 8)
#   Local fTable chars: 6
#   Local sequence length: 57344
#   Local sequence overlap between two consecutive indexes: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 1
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
#   Time to read SNPs and splice sites: 00:00:00
# Using parameters --bmax 30175 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 30175 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:00
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 1, merged 6; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 1, merged 0; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 20115.8 (target: 30174)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering GFM loop
# Getting block 1 of 8
# Getting block 2 of 8
#   Reserving size (30175) for bucket 2
#   Reserving size (30175) for bucket 1
#   Calculating Z arrays for bucket 2
# Getting block 3 of 8
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 2:
#   Reserving size (30175) for bucket 3
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 1:
#   Entering block accumulator loop for bucket 3:
#   bucket 1: 10%
#   bucket 3: 10%
#   bucket 2: 10%
#   bucket 1: 20%
#   bucket 3: 20%
#   bucket 1: 30%
#   bucket 2: 20%
#   bucket 1: 40%
#   bucket 3: 30%
#   bucket 2: 30%
#   bucket 1: 50%
#   bucket 3: 40%
#   bucket 2: 40%
#   bucket 1: 60%
#   bucket 1: 70%
#   bucket 3: 50%
#   bucket 2: 50%
#   bucket 1: 80%
#   bucket 3: 60%
#   bucket 2: 60%
#   bucket 1: 90%
#   bucket 3: 70%
#   bucket 2: 70%
#   bucket 1: 100%
#   Sorting block of length 28883 for bucket 1
#   (Using difference cover)
#   bucket 3: 80%
#   bucket 2: 80%
#   bucket 3: 90%
#   bucket 2: 90%
#   bucket 3: 100%
#   Sorting block of length 8869 for bucket 3
#   (Using difference cover)
#   bucket 2: 100%
#   Sorting block of length 25637 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 8870 for bucket 3
# Getting block 4 of 8
#   Reserving size (30175) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   bucket 4: 20%
#   bucket 4: 30%
#   bucket 4: 40%
#   bucket 4: 50%
#   bucket 4: 60%
#   bucket 4: 70%
#   bucket 4: 80%
#   bucket 4: 90%
#   bucket 4: 100%
#   Sorting block of length 23808 for bucket 4
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 28884 for bucket 1
# Getting block 5 of 8
#   Reserving size (30175) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   Sorting block time: 00:00:00
# Returning block of 25638 for bucket 2
# Getting block 6 of 8
#   Reserving size (30175) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 5: 10%
#   bucket 6: 10%
#   bucket 6: 20%
#   bucket 5: 20%
#   bucket 6: 30%
#   bucket 5: 30%
#   bucket 6: 40%
#   bucket 6: 50%
#   bucket 5: 40%
#   bucket 6: 60%
#   bucket 5: 50%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 5: 60%
#   bucket 6: 90%
#   bucket 5: 70%
#   bucket 6: 100%
#   Sorting block of length 14887 for bucket 6
#   (Using difference cover)
#   bucket 5: 80%
#   bucket 5: 90%
#   bucket 5: 100%
#   Sorting block of length 23737 for bucket 5
#   (Using difference cover)
#   Sorting block time: 00:00:01
# Returning block of 23809 for bucket 4
# Getting block 7 of 8
#   Reserving size (30175) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   bucket 7: 10%
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 25542 for bucket 7
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 14888 for bucket 6
# Getting block 8 of 8
#   Sorting block time: 00:00:00
#   Reserving size (30175) for bucket 8
#   Calculating Z arrays for bucket 8
#   Entering block accumulator loop for bucket 8:
#   bucket 8: 10%
#   bucket 8: 20%
#   bucket 8: 30%
#   bucket 8: 40%
#   bucket 8: 50%
#   bucket 8: 60%
#   bucket 8: 70%
#   bucket 8: 80%
#   bucket 8: 90%
#   bucket 8: 100%
#   Sorting block of length 9563 for bucket 8
#   (Using difference cover)
# Returning block of 23738 for bucket 5
#   Sorting block time: 00:00:00
# Returning block of 25543 for bucket 7
#   Sorting block time: 00:00:00
# Returning block of 9564 for bucket 8
# Exited GFM loop
# fchr[A]: 0
# fchr[C]: 44374
# fchr[G]: 75934
# fchr[T]: 110205
# fchr[$]: 160933
# Exiting GFM::buildToDisk()
# Returning from initFromVector
# Wrote 4248209 bytes to primary GFM file: junk2_dbs/indexes/hisat2/CFLAR_HIPK3.1.ht2
# Wrote 40240 bytes to secondary GFM file: junk2_dbs/indexes/hisat2/CFLAR_HIPK3.2.ht2
# Re-opening _in1 and _in2 as input streams
# Returning from GFM constructor
# Returning from initFromVector
# Wrote 79869 bytes to primary GFM file: junk2_dbs/indexes/hisat2/CFLAR_HIPK3.5.ht2
# Wrote 40754 bytes to secondary GFM file: junk2_dbs/indexes/hisat2/CFLAR_HIPK3.6.ht2
# Re-opening _in5 and _in5 as input streams
# Returning from HierEbwt constructor
# Headers:
#     len: 160933
#     gbwtLen: 160934
#     nodes: 160934
#     sz: 40234
#     gbwtSz: 40234
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 0
#     eftabSz: 0
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 10059
#     offsSz: 40236
#     lineSz: 64
#     sideSz: 64
#     sideGbwtSz: 48
#     sideGbwtLen: 192
#     numSides: 839
#     numLines: 839
#     gbwtTotLen: 53696
#     gbwtTotSz: 53696
#     reverse: 0
#     linearFM: Yes
# Total time for call to driver() for forward index: 00:00:01
# segemehl.x -d /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa -x junk2_dbs/indexes/segemehl/CFLAR_HIPK3.idx
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reading database sequences.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: 2 database sequences found.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: total length of db sequences: 160933
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alphabet of size (6): ACGT~
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: size of db sequence: 160935
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: constructing suftab.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusort: classify
# init bit array of 20117
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusort: getting bit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: not bit alurusort: alloc B of size 73707
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusort: initbitarray of size 73707
# init bit array of 9214
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusort: Qmaxdist in cl of size 160935
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusort: scan B
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusort: substringsort
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: setting bit array to zero
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: allocating space for buckets and buffers
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: memsetting
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: substring sort ... ok
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: checking valbitarray
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: enter Tprime calculation[SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: init arrays
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: scan B
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: iterating i=160935 elements with lenB=73707
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: exit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: enter alursortint
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: classify int
# init bit array of 9214
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: getting bit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: init bcktsA
# init bit array of 9214
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: countingsort
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countingsortint: init buffers and A
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: setting buffer to zero
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (1 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (2 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (3 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (to set borders)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: exiting
# init bit array of 3718
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: allocating B with 29741 elements
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: iterating to lenA=73707
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: exiting
# init bit array of 9214
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter get listsL
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsL: memsetting list of 73705 elements
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsL: iter from 73706 down to 0
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: scanning A (73707 elems)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: scanning accdist (26 elems) (1)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: scanning accdist (26 elems) (2)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsL: exit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: sort listsL
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistL: allocating stuff
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistL: iterating 29741 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistL: looping 73705 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistL: iterating 73707 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistsL: exiting happily!
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter tprime
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: init arrays
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: scan B
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: iterating i=73707 elements with lenB=29741
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: exit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter alurusortint
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: classify int
# init bit array of 3718
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: getting bit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: init bcktsA
# init bit array of 3718
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: countingsort
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countingsortint: init buffers and A
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: setting buffer to zero
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (1 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (2 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (3 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (to set borders)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: exiting
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: Sorting type S suffixes. Init bcktsB.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: 13304	16437	29741
#
# init bit array of 1663
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: allocating B with 13304 elements
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: iterating to lenA=29741
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: exiting
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter Qmaxdist
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter Qdist
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter distCount
# init bit array of 3718
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter get listsS
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: memsetting list of 29739 elements
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: iter up to 29741
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: scan A
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: set accidst
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: exiting
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: freeing stuff
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter sortlistsS
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistS: allocating stuff
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistS: iterating 13304 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistS: looping 29739 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistS: iterating 29741 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistsS: exiting happily!
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter tprime
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: init arrays
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: scan B
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: iterating i=29741 elements with lenB=13304
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: exit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter alurusortint
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: classify int
# init bit array of 1663
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: getting bit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: init bcktsA
# init bit array of 1663
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: countingsort
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countingsortint: init buffers and A
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: setting buffer to zero
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (1 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (2 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (3 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (to set borders)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: exiting
# init bit array of 748
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: allocating B with 5979 elements
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: iterating to lenA=13304
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: exiting
# init bit array of 1663
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter get listsL
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsL: memsetting list of 13302 elements
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsL: iter from 13303 down to 0
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: scanning A (13304 elems)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: scanning accdist (10 elems) (1)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: scanning accdist (10 elems) (2)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsL: exit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: sort listsL
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistL: allocating stuff
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistL: iterating 5979 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistL: looping 13302 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistL: iterating 13304 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistsL: exiting happily!
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter tprime
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: init arrays
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: scan B
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: iterating i=13304 elements with lenB=5979
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: tprime: exit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter alurusortint
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: classify int
# init bit array of 748
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: getting bit
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: init bcktsA
# init bit array of 748
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: countingsort
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countingsortint: init buffers and A
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: setting buffer to zero
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (1 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (2 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (3 of 3)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: scanning buffer (to set borders)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: countsortint: exiting
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: Sorting type S suffixes. Init bcktsB.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: 2638	3341	5979
#
# init bit array of 330
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: allocating B with 2638 elements
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: iterating to lenA=5979
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: arrayB: exiting
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter Qmaxdist
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter Qdist
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter distCount
# init bit array of 748
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter get listsS
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: memsetting list of 5977 elements
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: iter up to 5979
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: scan A
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: set accidst
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: getlistsS: exiting
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: freeing stuff
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: enter sortlistsS
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistS: allocating stuff
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistS: iterating 2638 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistS: looping 5977 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistS: iterating 5979 elems[SEGEMEHL] Mon Aug  7 03:44:31 2017: sortlistsS: exiting happily!
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: alurusortint: valbitarraysortedS.
# init bit array of 748
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstructintL
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: init
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: iteration over 13304 elems
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: scan B (size: 5979)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: exitinit bit array of 1663
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstructintS
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: init
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: iteration over 29741 elems
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: scan B (size: 13304)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: exitinit bit array of 3718
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstructintL
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: init
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: iteration over 73707 elems
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: scan B (size: 29741)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: exitinit bit array of 9214
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstructcharS
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: init
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: iteration over 160935 elems
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: scan B (size: 73707)
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: reconstruct: exit[SEGEMEHL] Mon Aug  7 03:44:31 2017: enter aluruSuffixArrayS start
# init bit array of 20117
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: constructing inv_suftab (160935).
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: inv_suftab constructed.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: constructing lcp.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: deleting inv_suftab
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: constructing child tab.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: constructing suffix links.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: constructing id.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: constructing suflinks - bottom up.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: constructing suflinks - top down.
# suflink construction. pushes: 107830, maxstack: 60
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: building  the suffix array has taken 0.000000 seconds.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: total length of suffix array was 160933.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017: writing suffix array 'junk2_dbs/indexes/segemehl/CFLAR_HIPK3.idx' to disk.
# [SEGEMEHL] Mon Aug  7 03:44:31 2017:
# Goodbye.
#  "Ich hol' jetzt die Hilti!" (Ein verzweifelter Bauarbeiter)
# bowtie2-build -f --seed 1 --threads 3 /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa junk2_dbs/indexes/bowtie2/CFLAR_HIPK3
# Settings:
#   Output files: "junk2_dbs/indexes/bowtie2/CFLAR_HIPK3.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 1
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa
# Building a SMALL index
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
# bmax according to bmaxDivN setting: 40233
# Using parameters --bmax 30175 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 30175 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:00
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 1, merged 6; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Split 1, merged 0; iterating...
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 20115.8 (target: 30174)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 8
#   Reserving size (30175) for bucket 1
# Getting block 2 of 8
#   Reserving size (30175) for bucket 2
# Getting block 3 of 8
#   Reserving size (30175) for bucket 3
#   Calculating Z arrays for bucket 2
#   Calculating Z arrays for bucket 3
#   Entering block accumulator loop for bucket 2:
#   Entering block accumulator loop for bucket 3:
#   bucket 2: 10%
#   bucket 3: 10%
#   bucket 2: 20%
#   bucket 3: 20%
#   bucket 2: 30%
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 1:
#   bucket 2: 40%
#   bucket 1: 10%
#   bucket 2: 50%
#   bucket 1: 20%
#   bucket 2: 60%
#   bucket 2: 70%
#   bucket 1: 30%
#   bucket 2: 80%
#   bucket 1: 40%
#   bucket 2: 90%
#   bucket 1: 50%
#   bucket 1: 60%
#   bucket 2: 100%
#   Sorting block of length 25637 for bucket 2
#   (Using difference cover)
#   bucket 3: 30%
#   bucket 1: 70%
#   bucket 1: 80%
#   bucket 3: 40%
#   bucket 1: 90%
#   bucket 3: 50%
#   bucket 1: 100%
#   Sorting block of length 28883 for bucket 1
#   (Using difference cover)
#   bucket 3: 60%
#   bucket 3: 70%
#   bucket 3: 80%
#   bucket 3: 90%
#   bucket 3: 100%
#   Sorting block of length 8869 for bucket 3
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 8870 for bucket 3
#   Sorting block time: 00:00:00
# Returning block of 25638 for bucket 2
# Getting block 4 of 8
#   Reserving size (30175) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
# Getting block 5 of 8
#   Reserving size (30175) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 4: 20%
#   Sorting block time: 00:00:00
# Returning block of 28884 for bucket 1
#   bucket 4: 30%
#   bucket 5: 10%
#   bucket 4: 40%
#   bucket 5: 20%
#   bucket 4: 50%
#   bucket 5: 30%
# Getting block 6 of 8
#   Reserving size (30175) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 4: 60%
#   bucket 5: 40%
#   bucket 6: 10%
#   bucket 5: 50%
#   bucket 4: 70%
#   bucket 6: 20%
#   bucket 5: 60%
#   bucket 6: 30%
#   bucket 4: 80%
#   bucket 5: 70%
#   bucket 5: 80%
#   bucket 4: 90%
#   bucket 6: 40%
#   bucket 5: 90%
#   bucket 4: 100%
#   Sorting block of length 23808 for bucket 4
#   (Using difference cover)
#   bucket 6: 50%
#   bucket 5: 100%
#   Sorting block of length 23737 for bucket 5
#   (Using difference cover)
#   bucket 6: 60%
#   bucket 6: 70%
#   bucket 6: 80%
#   bucket 6: 90%
#   Sorting block time: 00:00:00
# Returning block of 23809 for bucket 4
#   bucket 6: 100%
#   Sorting block of length 14887 for bucket 6
#   (Using difference cover)
# Getting block 7 of 8
#   Reserving size (30175) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   Sorting block time: 00:00:00
# Returning block of 23738 for bucket 5
#   bucket 7: 10%
#   bucket 7: 20%
# Getting block 8 of 8
#   Reserving size (30175) for bucket 8
#   Calculating Z arrays for bucket 8
#   Entering block accumulator loop for bucket 8:
#   bucket 7: 30%
#   Sorting block time: 00:00:00
# Returning block of 14888 for bucket 6
#   bucket 8: 10%
#   bucket 7: 40%
#   bucket 8: 20%
#   bucket 7: 50%
#   bucket 8: 30%
#   bucket 7: 60%
#   bucket 8: 40%
#   bucket 7: 70%
#   bucket 8: 50%
#   bucket 8: 60%
#   bucket 7: 80%
#   bucket 8: 70%
#   bucket 7: 90%
#   bucket 8: 80%
#   bucket 7: 100%
#   Sorting block of length 25542 for bucket 7
#   (Using difference cover)
#   bucket 8: 90%
#   bucket 8: 100%
#   Sorting block of length 9563 for bucket 8
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 9564 for bucket 8
#   Sorting block time: 00:00:00
# Returning block of 25543 for bucket 7
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 44374
# fchr[G]: 75934
# fchr[T]: 110205
# fchr[$]: 160933
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 4248189 bytes to primary EBWT file: junk2_dbs/indexes/bowtie2/CFLAR_HIPK3.1.bt2
# Wrote 40240 bytes to secondary EBWT file: junk2_dbs/indexes/bowtie2/CFLAR_HIPK3.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 160933
#     bwtLen: 160934
#     sz: 40234
#     bwtSz: 40234
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 10059
#     offsSz: 40236
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 839
#     numLines: 839
#     ebwtTotLen: 53696
#     ebwtTotSz: 53696
#     color: 0
#     reverse: 0
# Total time for call to driver() for forward index: 00:00:00
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
#   Time to reverse reference sequence: 00:00:00
# bmax according to bmaxDivN setting: 40233
# Using parameters --bmax 30175 --dcv 1024
#   Doing ahead-of-time memory usage test
#   Passed!  Constructing with these parameters: --bmax 30175 --dcv 1024
# Constructing suffix-array element generator
# Building DifferenceCoverSample
#   Building sPrime
#   Building sPrimeOrder
#   V-Sorting samples
#   V-Sorting samples time: 00:00:00
#   Allocating rank array
#   Ranking v-sort output
#   Ranking v-sort output time: 00:00:00
#   Invoking Larsson-Sadakane on ranks
#   Invoking Larsson-Sadakane on ranks time: 00:00:00
#   Sanity-checking and returning
# Building samples
# Reserving space for 12 sample suffixes
# Generating random suffixes
# QSorting 12 sample offsets, eliminating duplicates
# QSorting sample offsets, eliminating duplicates time: 00:00:00
# Multikey QSorting 12 samples
#   (Using difference cover)
#   Multikey QSorting samples time: 00:00:00
# Calculating bucket sizes
# Splitting and merging
#   Splitting and merging time: 00:00:00
# Avg bucket size: 22989.6 (target: 30174)
# Converting suffix-array elements to index image
# Allocating ftab, absorbFtab
# Entering Ebwt loop
# Getting block 1 of 7
# Getting block 2 of 7
# Getting block 3 of 7
#   Reserving size (30175) for bucket 2
#   Reserving size (30175) for bucket 3
#   Calculating Z arrays for bucket 2
#   Calculating Z arrays for bucket 3
#   Reserving size (30175) for bucket 1
#   Calculating Z arrays for bucket 1
#   Entering block accumulator loop for bucket 3:
#   Entering block accumulator loop for bucket 2:
#   Entering block accumulator loop for bucket 1:
#   bucket 3: 10%
#   bucket 1: 10%
#   bucket 2: 10%
#   bucket 1: 20%
#   bucket 3: 20%
#   bucket 2: 20%
#   bucket 1: 30%
#   bucket 3: 30%
#   bucket 2: 30%
#   bucket 1: 40%
#   bucket 3: 40%
#   bucket 2: 40%
#   bucket 1: 50%
#   bucket 3: 50%
#   bucket 1: 60%
#   bucket 2: 50%
#   bucket 3: 60%
#   bucket 1: 70%
#   bucket 2: 60%
#   bucket 3: 70%
#   bucket 1: 80%
#   bucket 2: 70%
#   bucket 3: 80%
#   bucket 1: 90%
#   bucket 3: 90%
#   bucket 2: 80%
#   bucket 1: 100%
#   Sorting block of length 18918 for bucket 1
#   (Using difference cover)
#   bucket 3: 100%
#   Sorting block of length 16013 for bucket 3
#   (Using difference cover)
#   bucket 2: 90%
#   bucket 2: 100%
#   Sorting block of length 21607 for bucket 2
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 16014 for bucket 3
# Getting block 4 of 7
#   Reserving size (30175) for bucket 4
#   Calculating Z arrays for bucket 4
#   Entering block accumulator loop for bucket 4:
#   bucket 4: 10%
#   Sorting block time: 00:00:00
# Returning block of 18919 for bucket 1
#   bucket 4: 20%
#   bucket 4: 30%
#   Sorting block time: 00:00:00
# Returning block of 21608 for bucket 2
#   bucket 4: 40%
# Getting block 5 of 7
#   Reserving size (30175) for bucket 5
#   Calculating Z arrays for bucket 5
#   Entering block accumulator loop for bucket 5:
#   bucket 4: 50%
#   bucket 5: 10%
#   bucket 4: 60%
# Getting block 6 of 7
#   Reserving size (30175) for bucket 6
#   Calculating Z arrays for bucket 6
#   Entering block accumulator loop for bucket 6:
#   bucket 5: 20%
#   bucket 4: 70%
#   bucket 6: 10%
#   bucket 5: 30%
#   bucket 4: 80%
#   bucket 6: 20%
#   bucket 5: 40%
#   bucket 5: 50%
#   bucket 6: 30%
#   bucket 5: 60%
#   bucket 6: 40%
#   bucket 5: 70%
#   bucket 6: 50%
#   bucket 4: 90%
#   bucket 5: 80%
#   bucket 6: 60%
#   bucket 4: 100%
#   Sorting block of length 21979 for bucket 4
#   (Using difference cover)
#   bucket 5: 90%
#   bucket 6: 70%
#   bucket 5: 100%
#   Sorting block of length 28403 for bucket 5
#   (Using difference cover)
#   bucket 6: 80%
#   bucket 6: 90%
#   bucket 6: 100%
#   Sorting block of length 29207 for bucket 6
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 21980 for bucket 4
# Getting block 7 of 7
#   Reserving size (30175) for bucket 7
#   Calculating Z arrays for bucket 7
#   Entering block accumulator loop for bucket 7:
#   Sorting block time: 00:00:00
# Returning block of 28404 for bucket 5
#   Sorting block time: 00:00:00
# Returning block of 29208 for bucket 6
#   bucket 7: 10%
#   bucket 7: 20%
#   bucket 7: 30%
#   bucket 7: 40%
#   bucket 7: 50%
#   bucket 7: 60%
#   bucket 7: 70%
#   bucket 7: 80%
#   bucket 7: 90%
#   bucket 7: 100%
#   Sorting block of length 24800 for bucket 7
#   (Using difference cover)
#   Sorting block time: 00:00:00
# Returning block of 24801 for bucket 7
# Exited Ebwt loop
# fchr[A]: 0
# fchr[C]: 44374
# fchr[G]: 75934
# fchr[T]: 110205
# fchr[$]: 160933
# Exiting Ebwt::buildToDisk()
# Returning from initFromVector
# Wrote 4248189 bytes to primary EBWT file: junk2_dbs/indexes/bowtie2/CFLAR_HIPK3.rev.1.bt2
# Wrote 40240 bytes to secondary EBWT file: junk2_dbs/indexes/bowtie2/CFLAR_HIPK3.rev.2.bt2
# Re-opening _in1 and _in2 as input streams
# Returning from Ebwt constructor
# Headers:
#     len: 160933
#     bwtLen: 160934
#     sz: 40234
#     bwtSz: 40234
#     lineRate: 6
#     offRate: 4
#     offMask: 0xfffffff0
#     ftabChars: 10
#     eftabLen: 20
#     eftabSz: 80
#     ftabLen: 1048577
#     ftabSz: 4194308
#     offsLen: 10059
#     offsSz: 40236
#     lineSz: 64
#     sideSz: 64
#     sideBwtSz: 48
#     sideBwtLen: 192
#     numSides: 839
#     numLines: 839
#     ebwtTotLen: 53696
#     ebwtTotSz: 53696
#     color: 0
#     reverse: 1
# Total time for backward call to driver() for mirror index: 00:00:00
# cd junk2_dbs/indexes/star/CFLAR_HIPK3 && STAR --runMode genomeGenerate --runThreadN 3 --genomeFastaFiles /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa --genomeDir . && cd /headless/CirComPara/test_circompara/analysis
# Aug 07 03:44:31 ..... started STAR run
# Aug 07 03:44:31 ... starting to generate Genome files
# Aug 07 03:44:31 ... starting to sort Suffix Array. This may take a long time...
# Aug 07 03:44:31 ... sorting Suffix Array chunks and saving them to disk...
# Aug 07 03:44:31 ... loading chunks from disk, packing SA...
# Aug 07 03:44:31 ... finished generating suffix array
# Aug 07 03:44:31 ... generating Suffix Array index
# Aug 07 03:44:34 ... completed Suffix Array index
# Aug 07 03:44:34 ... writing Genome to disk ...
# Aug 07 03:44:34 ... writing Suffix Array to disk ...
# Aug 07 03:44:34 ... writing SAindex to disk
# Aug 07 03:44:58 ..... finished successfully
# bwa index -a bwtsw -p junk2_dbs/indexes/bwa/CFLAR_HIPK3 /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa
# [bwa_index] Pack FASTA... 0.00 sec
# [bwa_index] Construct BWT for the packed sequence...
# [BWTIncCreate] textLength=321866, availableWord=409398
# [bwt_gen] Finished constructing BWT in 5 iterations.
# [bwa_index] 0.06 seconds elapse.
# [bwa_index] Update BWT... 0.00 sec
# [bwa_index] Pack forward-only FASTA... 0.00 sec
# [bwa_index] Construct SA from BWT and Occ... 0.01 sec
# [main] Version: 0.7.15-r1140
# [main] CMD: bwa index -a bwtsw -p junk2_dbs/indexes/bwa/CFLAR_HIPK3 /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa
# [main] Real time: 5.805 sec; CPU: 0.140 sec
# java -jar /headless/CirComPara/tools/Trimmomatic-0.36/trimmomatic-0.36.jar PE -threads 3 /headless/CirComPara/test_circompara/reads/readsA_1.fastq.gz /headless/CirComPara/test_circompara/reads/readsA_2.fastq.gz samples/sample_A/processings/preprocess/trimmomatic/readsA_1.fq.P.qtrim.gz samples/sample_A/processings/preprocess/trimmomatic/readsA_1.fq.U.qtrim.gz samples/sample_A/processings/preprocess/trimmomatic/readsA_2.fq.P.qtrim.gz samples/sample_A/processings/preprocess/trimmomatic/readsA_2.fq.U.qtrim.gz ILLUMINACLIP:/headless/CirComPara/tools/Trimmomatic-0.36/adapters/TruSeq3-PE-2.fa:2:30:10 MAXINFO:40:0.5 LEADING:20 TRAILING:20 SLIDINGWINDOW:4:30 MINLEN:35 AVGQUAL:30 2> samples/sample_A/processings/preprocess/trimmomatic/trimmomatic.log
# cd /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/hisat2_out && hisat2 -x /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/hisat2/CFLAR_HIPK3 --dta --dta-cufflinks --rg-id sample_A --no-discordant --no-mixed --no-overlap -p 3 -1 /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/preprocess/trimmomatic/readsA_1.fq.P.qtrim.gz -2 /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/preprocess/trimmomatic/readsA_2.fq.P.qtrim.gz 2> /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/hisat2_out/sample_A_hisat2.log | samtools view -hu -@ 3 - | samtools sort -O 'bam' -@ 3 -T hisat2_sample_A > /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/hisat2_out/sample_A_hisat2.bam && cd /headless/CirComPara/test_circompara/analysis
# samtools fastq -f 12 -F 3328 -n -s /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/singleton.fastq -1 /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/unmapped_1.fastq -2 /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/unmapped_2.fastq samples/sample_A/processings/hisat2_out/sample_A_hisat2.bam && gzip /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/unmapped_1.fastq && gzip /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/unmapped_2.fastq && gzip /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/singleton.fastq
# [M::bam2fq_mainloop_singletontrack] discarded 0 singletons
# [M::bam2fq_mainloop_singletontrack] processed 3540 reads
# cd /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/CIRCexplorer/star_out && STAR --outSAMstrandField intronMotif --outSAMtype BAM SortedByCoordinate --chimSegmentMin 20 --chimOutType WithinBAM --runThreadN 3 --genomeDir /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/star/CFLAR_HIPK3 --readFilesIn /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/unmapped_1.fastq.gz /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/unmapped_2.fastq.gz --readFilesCommand zcat --sjdbGTFfile /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf && cd /headless/CirComPara/test_circompara/analysis
# Aug 07 03:45:09 ..... started STAR run
# Aug 07 03:45:09 ..... loading genome
# Aug 07 03:45:09 ..... processing annotations GTF
# Aug 07 03:45:09 ..... inserting junctions into the genome indices
# Aug 07 03:45:17 ..... started mapping
# Aug 07 03:45:18 ..... started sorting BAM
# Aug 07 03:45:18 ..... finished successfully
# star_parse.py /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/CIRCexplorer/star_out/Chimeric.out.junction /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/CIRCexplorer/fusion_junction.txt
# cd /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/CIRCexplorer && CIRCexplorer.py -g /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa -r /headless/CirComPara/test_circompara/analysis/junk2_dbs/CFLAR_HIPK3.genePred.wgn -j /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/CIRCexplorer/fusion_junction.txt && cd /headless/CirComPara/test_circompara/analysis
# Start CIRCexplorer 1.1.10
# Start to annotate fusion junctions...
# Annotated 3 fusion junctions!
# Start to fix fusion junctions...
# Fixed 0 fusion junctions!
# java -jar /headless/CirComPara/tools/Trimmomatic-0.36/trimmomatic-0.36.jar PE -threads 3 /headless/CirComPara/test_circompara/reads/readsB_1.fastq.gz /headless/CirComPara/test_circompara/reads/readsB_2.fastq.gz samples/sample_B/processings/preprocess/trimmomatic/readsB_1.fq.P.qtrim.gz samples/sample_B/processings/preprocess/trimmomatic/readsB_1.fq.U.qtrim.gz samples/sample_B/processings/preprocess/trimmomatic/readsB_2.fq.P.qtrim.gz samples/sample_B/processings/preprocess/trimmomatic/readsB_2.fq.U.qtrim.gz ILLUMINACLIP:/headless/CirComPara/tools/Trimmomatic-0.36/adapters/TruSeq3-PE-2.fa:2:30:10 MAXINFO:40:0.5 LEADING:20 TRAILING:20 SLIDINGWINDOW:4:30 MINLEN:35 AVGQUAL:30 2> samples/sample_B/processings/preprocess/trimmomatic/trimmomatic.log
# cd /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/hisat2_out && hisat2 -x /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/hisat2/CFLAR_HIPK3 --dta --dta-cufflinks --rg-id sample_B --no-discordant --no-mixed --no-overlap -p 3 -1 /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/preprocess/trimmomatic/readsB_1.fq.P.qtrim.gz -2 /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/preprocess/trimmomatic/readsB_2.fq.P.qtrim.gz 2> /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/hisat2_out/sample_B_hisat2.log | samtools view -hu -@ 3 - | samtools sort -O 'bam' -@ 3 -T hisat2_sample_B > /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/hisat2_out/sample_B_hisat2.bam && cd /headless/CirComPara/test_circompara/analysis
# samtools fastq -f 12 -F 3328 -n -s /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/singleton.fastq -1 /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/unmapped_1.fastq -2 /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/unmapped_2.fastq samples/sample_B/processings/hisat2_out/sample_B_hisat2.bam && gzip /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/unmapped_1.fastq && gzip /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/unmapped_2.fastq && gzip /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/singleton.fastq
# [M::bam2fq_mainloop_singletontrack] discarded 0 singletons
# [M::bam2fq_mainloop_singletontrack] processed 1432 reads
# cd /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/CIRCexplorer/star_out && STAR --outSAMstrandField intronMotif --outSAMtype BAM SortedByCoordinate --chimSegmentMin 20 --chimOutType WithinBAM --runThreadN 3 --genomeDir /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/star/CFLAR_HIPK3 --readFilesIn /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/unmapped_1.fastq.gz /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/unmapped_2.fastq.gz --readFilesCommand zcat --sjdbGTFfile /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf && cd /headless/CirComPara/test_circompara/analysis
# Aug 07 03:45:21 ..... started STAR run
# Aug 07 03:45:21 ..... loading genome
# Aug 07 03:45:21 ..... processing annotations GTF
# Aug 07 03:45:21 ..... inserting junctions into the genome indices
# Aug 07 03:45:29 ..... started mapping
# Aug 07 03:45:30 ..... started sorting BAM
# Aug 07 03:45:30 ..... finished successfully
# star_parse.py /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/CIRCexplorer/star_out/Chimeric.out.junction /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/CIRCexplorer/fusion_junction.txt
# cd /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/CIRCexplorer && CIRCexplorer.py -g /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa -r /headless/CirComPara/test_circompara/analysis/junk2_dbs/CFLAR_HIPK3.genePred.wgn -j /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/CIRCexplorer/fusion_junction.txt && cd /headless/CirComPara/test_circompara/analysis
# Start CIRCexplorer 1.1.10
# Start to annotate fusion junctions...
# Annotated 6 fusion junctions!
# Start to fix fusion junctions...
# Fixed 0 fusion junctions!
# /headless/CirComPara/src/CIRCexplorer_compare.R -l sample_A,sample_B -i samples/sample_A/processings/circRNAs/CIRCexplorer/CIRCexplorer_circ.txt,samples/sample_B/processings/circRNAs/CIRCexplorer/CIRCexplorer_circ.txt -o circRNA_collection/CIRCexplorer_compared.csv
# segemehl.x -s -i /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/segemehl/CFLAR_HIPK3.idx -d /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa -q samples/sample_A/processings/unmapped_reads/unmapped_1.fastq.gz -p samples/sample_A/processings/unmapped_reads/unmapped_2.fastq.gz -S -t 3 -u samples/sample_A/processings/circRNAs/segemehl/processings_unmatched.fastq -C -T | samtools view -u -@3 - | samtools sort -@3 -O 'bam' -T segemehl_processings > samples/sample_A/processings/circRNAs/segemehl/processings.bam && gzip samples/sample_A/processings/circRNAs/segemehl/processings_unmatched.fastq
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading queries in 'samples/sample_A/processings/unmapped_reads/unmapped_1.fastq.gz'.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: 1770 query sequences found.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading mates in 'samples/sample_A/processings/unmapped_reads/unmapped_2.fastq.gz'.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: 1770 mate sequences found.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading database sequences.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: 2 database sequences found.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: total length of db sequences: 160933
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading suffix array '/headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/segemehl/CFLAR_HIPK3.idx' from disk.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading lcpc/vtab.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading childtab.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading suflinks.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading lsint id.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: read suffix array '/headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/segemehl/CFLAR_HIPK3.idx' with 160935 elements.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: md5 keys of index and db match.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: reading the suffix array has taken 0.000000 seconds.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: starting 3 threads.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: 590 reads in thread 0.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: 590 reads in thread 1.
# [SEGEMEHL] Mon Aug  7 03:45:31 2017: 590 reads in thread 2.
# [SEGEMEHL] Mon Aug  7 03:45:32 2017: threaded matching w/ suffixarray has taken 1.000000 seconds.
# [SEGEMEHL] Mon Aug  7 03:45:32 2017:
# Goodbye.
#  "Ich bin neu in der Hamburger Schule" (Tocotronic)
# samtools view -u -@3 samples/sample_A/processings/circRNAs/segemehl/processings.bam | samtools sort -@3 -O 'sam' -T processings | gzip > samples/sample_A/processings/circRNAs/testrealign/processings_sorted.sam.gz
# zcat samples/sample_A/processings/circRNAs/testrealign/processings_sorted.sam.gz | samtools view -F 4 - | cut -f 1 | sort | uniq | wc -l > samples/sample_A/processings/circRNAs/testrealign/segemehl_mapped_reads_count.txt
# segemehl.x -s -i /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/segemehl/CFLAR_HIPK3.idx -d /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa -q samples/sample_B/processings/unmapped_reads/unmapped_1.fastq.gz -p samples/sample_B/processings/unmapped_reads/unmapped_2.fastq.gz -S -t 3 -u samples/sample_B/processings/circRNAs/segemehl/processings_unmatched.fastq -C -T | samtools view -u -@3 - | samtools sort -@3 -O 'bam' -T segemehl_processings > samples/sample_B/processings/circRNAs/segemehl/processings.bam && gzip samples/sample_B/processings/circRNAs/segemehl/processings_unmatched.fastq
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: reading queries in 'samples/sample_B/processings/unmapped_reads/unmapped_1.fastq.gz'.
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: 716 query sequences found.
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: reading mates in 'samples/sample_B/processings/unmapped_reads/unmapped_2.fastq.gz'.
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: 716 mate sequences found.
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: reading database sequences.
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: 2 database sequences found.
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: total length of db sequences: 160933
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: reading suffix array '/headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/segemehl/CFLAR_HIPK3.idx' from disk.
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: reading lcpc/vtab.
# [SEGEMEHL] Mon Aug  7 03:45:33 2017: reading childtab.
# ...
#
#   |...................                                              |  30%
# label: show_circrnas_per_method (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#   |....................                                             |  31%
#   ordinary text without R code
#
#   |......................                                           |  33%
# label: show_circrnas_shared (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#
#   |.......................                                          |  35%
#    inline R code fragments
#
#   |........................                                         |  37%
# label: show_circrnas_2reads_2methods_sample (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#
#   |.........................                                        |  39%
#   ordinary text without R code
#
#   |..........................                                       |  41%
# label: plot_circrnas_2reads_2methods_sample (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#
#   |............................                                     |  43%
#    inline R code fragments
#
#   |.............................                                    |  44%
# label: circrnas_per_gene (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#
#   |..............................                                   |  46%
#    inline R code fragments
#
#   |...............................                                  |  48%
# label: plot_circrnas_per_gene (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#
#   |................................                                 |  50%
#   ordinary text without R code
#
#   |..................................                               |  52%
# label: show_circrnas_categories (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#
#   |...................................                              |  54%
#    inline R code fragments
#
#   |....................................                             |  56%
# label: show_gene_expressed_by_sample
#   |.....................................                            |  57%
#   ordinary text without R code
#
#   |.......................................                          |  59%
# label: plot_gene_expressed_by_sample
#   |........................................                         |  61%
#   ordinary text without R code
#
#   |.........................................                        |  63%
# label: show_reliable_circrnas_expression (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#
#   |..........................................                       |  65%
#   ordinary text without R code
#
#   |...........................................                      |  67%
# label: plot_reliable_circrnas_expression (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi TRUE
#
#   |.............................................                    |  69%
#   ordinary text without R code
#
#   |..............................................                   |  70%
# label: show_gene_expression
#   |...............................................                  |  72%
#   ordinary text without R code
#
#   |................................................                 |  74%
# label: plot_gene_expression
#   |.................................................                |  76%
#   ordinary text without R code
#
#   |...................................................              |  78%
# label: plot_circ_gene_expr
# notch went outside hinges. Try setting notch=FALSE.
# notch went outside hinges. Try setting notch=FALSE.
# notch went outside hinges. Try setting notch=FALSE.
# notch went outside hinges. Try setting notch=FALSE.
#   |....................................................             |  80%
#   ordinary text without R code
#
#   |.....................................................            |  81%
# label: cumulative_expression (with options)
# List of 1
#  $ include: logi FALSE
#
#   |......................................................           |  83%
#   ordinary text without R code
#
#   |.......................................................          |  85%
# label: cumulative_expression_box (with options)
# List of 2
#  $ fig.width : num 12
#  $ fig.height: num 4
#
#   |.........................................................        |  87%
#   ordinary text without R code
#
#   |..........................................................       |  89%
# label: correlation (with options)
# List of 2
#  $ echo   : logi FALSE
#  $ include: logi FALSE
#
#   |...........................................................      |  91%
#    inline R code fragments
#
#   |............................................................     |  93%
# label: corr_density_plot
#   |.............................................................    |  94%
#   ordinary text without R code
#
#   |...............................................................  |  96%
# label: correlations_box (with options)
# List of 2
#  $ fig.width : num 12
#  $ fig.height: num 4
#
#   |................................................................ |  98%
#   ordinary text without R code
#
#   |.................................................................| 100%
# label: session (with options)
# List of 1
#  $ echo: logi FALSE
#
#
# output file: /headless/CirComPara/test_circompara/analysis/circrna_analyze/circRNAs_analysis.knit.md
#
# /headless/.conda2/bin/pandoc +RTS -K512m -RTS /headless/CirComPara/test_circompara/analysis/circrna_analyze/circRNAs_analysis.utf8.md --to html --from markdown+autolink_bare_uris+ascii_identifiers+tex_math_single_backslash --output /headless/CirComPara/test_circompara/analysis/circrna_analyze/circRNAs_analysis.html --smart --email-obfuscation none --self-contained --standalone --section-divs --table-of-contents --toc-depth 2 --variable toc_float=1 --variable toc_selectors=h1,h2 --variable toc_smooth_scroll=1 --variable toc_print=1 --template /headless/CirComPara/tools/R_libs/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --number-sections --variable 'theme:readable' --include-in-header /tmp/RtmpqMXJsR/rmarkdown-str130248cdbde6.html --mathjax --variable 'mathjax-url:https://mathjax.rstudio.com/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML'
#
# Output created: circrna_analyze/circRNAs_analysis.html
# Warning messages:
# 1: Removed 3 rows containing non-finite values (stat_density).
# 2: Removed 3 rows containing non-finite values (stat_boxplot).
# grep Input samples/sample_A/processings/preprocess/trimmomatic/trimmomatic.log samples/sample_B/processings/preprocess/trimmomatic/trimmomatic.log > read_stats_collect/read_stats_collect.txt && cat samples/sample_A/processings/hisat2_out/sample_A_hisat2.log samples/sample_B/processings/hisat2_out/sample_B_hisat2.log >> read_stats_collect/read_stats_collect.txt
# grep ':C:' samples/sample_A/processings/circRNAs/testrealign/splicesites.bed | cut -f 4 | cut -f 2 -d: |sort | uniq -c | sort -k1,1n -k2,2n > samples/sample_A/processings/circRNAs/testrealign/processings_circular.junction.stats.txt
# cufflinks -q --no-update-check -p 3 --seed 0 -G /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf samples/sample_A/processings/hisat2_out/sample_A_hisat2.bam -o samples/sample_A/processings/cufflinks
# Command line:
# cufflinks -q --no-update-check -p 3 --seed 0 -G /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf samples/sample_A/processings/hisat2_out/sample_A_hisat2.bam -o samples/sample_A/processings/cufflinks
# [03:45:54] Loading reference annotation.
# [03:45:54] Inspecting reads and determining fragment length distribution.
# Processed 3 loci.
# Warning: Using default Gaussian distribution due to insufficient paired-end reads in open ranges.  It is recommended that correct parameters (--frag-len-mean and --frag-len-std-dev) be provided.
# > Map Properties:
# >	Normalized Map Mass: 40830.00
# >	Raw Map Mass: 40830.00
# >	Fragment Length Distribution: Truncated Gaussian (default)
# >	              Default Mean: 200
# >	           Default Std Dev: 80
# [03:45:55] Estimating transcript abundances.
# Processed 3 loci.
# samtools sort -n -@3 -O 'sam' -T sample_A samples/sample_A/processings/hisat2_out/sample_A_hisat2.bam |htseq-count -f sam -r name -s no - /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf > samples/sample_A/processings/htseq/sample_A.htseq_count.txt
# 632 GFF lines processed.
# 42655 SAM alignment pairs processed.
# echo "No reads in samples/sample_A/processings/preprocess/trimmomatic/readsA_1.fq.P.qtrim.gz" > samples/sample_A/processings/preprocess/fastqc_stats/readsA_1.fq.P.qtrim_fastqc.html && fastqc samples/sample_A/processings/preprocess/trimmomatic/readsA_1.fq.P.qtrim.gz -o samples/sample_A/processings/preprocess/fastqc_stats > samples/sample_A/processings/preprocess/fastqc_stats/readsA_1.fq.P.qtrim_fastqc.log 2> samples/sample_A/processings/preprocess/fastqc_stats/readsA_1.fq.P.qtrim_fastqc.err
# echo "No reads in samples/sample_A/processings/preprocess/trimmomatic/readsA_1.fq.U.qtrim.gz" > samples/sample_A/processings/preprocess/fastqc_stats/readsA_1.fq.U.qtrim_fastqc.html && fastqc samples/sample_A/processings/preprocess/trimmomatic/readsA_1.fq.U.qtrim.gz -o samples/sample_A/processings/preprocess/fastqc_stats > samples/sample_A/processings/preprocess/fastqc_stats/readsA_1.fq.U.qtrim_fastqc.log 2> samples/sample_A/processings/preprocess/fastqc_stats/readsA_1.fq.U.qtrim_fastqc.err
# echo "No reads in samples/sample_A/processings/preprocess/trimmomatic/readsA_2.fq.P.qtrim.gz" > samples/sample_A/processings/preprocess/fastqc_stats/readsA_2.fq.P.qtrim_fastqc.html && fastqc samples/sample_A/processings/preprocess/trimmomatic/readsA_2.fq.P.qtrim.gz -o samples/sample_A/processings/preprocess/fastqc_stats > samples/sample_A/processings/preprocess/fastqc_stats/readsA_2.fq.P.qtrim_fastqc.log 2> samples/sample_A/processings/preprocess/fastqc_stats/readsA_2.fq.P.qtrim_fastqc.err
# echo "No reads in samples/sample_A/processings/preprocess/trimmomatic/readsA_2.fq.U.qtrim.gz" > samples/sample_A/processings/preprocess/fastqc_stats/readsA_2.fq.U.qtrim_fastqc.html && fastqc samples/sample_A/processings/preprocess/trimmomatic/readsA_2.fq.U.qtrim.gz -o samples/sample_A/processings/preprocess/fastqc_stats > samples/sample_A/processings/preprocess/fastqc_stats/readsA_2.fq.U.qtrim_fastqc.log 2> samples/sample_A/processings/preprocess/fastqc_stats/readsA_2.fq.U.qtrim_fastqc.err
# echo "No reads in /headless/CirComPara/test_circompara/reads/readsA_1.fastq.gz" > samples/sample_A/read_statistics/fastqc_stats/readsA_1_fastqc.html && fastqc /headless/CirComPara/test_circompara/reads/readsA_1.fastq.gz -o samples/sample_A/read_statistics/fastqc_stats > samples/sample_A/read_statistics/fastqc_stats/readsA_1.fastq_fastqc.log 2> samples/sample_A/read_statistics/fastqc_stats/readsA_1.fastq_fastqc.err
# echo "No reads in /headless/CirComPara/test_circompara/reads/readsA_2.fastq.gz" > samples/sample_A/read_statistics/fastqc_stats/readsA_2_fastqc.html && fastqc /headless/CirComPara/test_circompara/reads/readsA_2.fastq.gz -o samples/sample_A/read_statistics/fastqc_stats > samples/sample_A/read_statistics/fastqc_stats/readsA_2.fastq_fastqc.log 2> samples/sample_A/read_statistics/fastqc_stats/readsA_2.fastq_fastqc.err
# grep ':C:' samples/sample_B/processings/circRNAs/testrealign/splicesites.bed | cut -f 4 | cut -f 2 -d: |sort | uniq -c | sort -k1,1n -k2,2n > samples/sample_B/processings/circRNAs/testrealign/processings_circular.junction.stats.txt
# cufflinks -q --no-update-check -p 3 --seed 0 -G /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf samples/sample_B/processings/hisat2_out/sample_B_hisat2.bam -o samples/sample_B/processings/cufflinks
# Command line:
# cufflinks -q --no-update-check -p 3 --seed 0 -G /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf samples/sample_B/processings/hisat2_out/sample_B_hisat2.bam -o samples/sample_B/processings/cufflinks
# [03:46:15] Loading reference annotation.
# [03:46:15] Inspecting reads and determining fragment length distribution.
# Processed 3 loci.
# Warning: Using default Gaussian distribution due to insufficient paired-end reads in open ranges.  It is recommended that correct parameters (--frag-len-mean and --frag-len-std-dev) be provided.
# > Map Properties:
# >	Normalized Map Mass: 18001.00
# >	Raw Map Mass: 18001.00
# >	Fragment Length Distribution: Truncated Gaussian (default)
# >	              Default Mean: 200
# >	           Default Std Dev: 80
# [03:46:15] Estimating transcript abundances.
# Processed 3 loci.
# samtools sort -n -@3 -O 'sam' -T sample_B samples/sample_B/processings/hisat2_out/sample_B_hisat2.bam |htseq-count -f sam -r name -s no - /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf > samples/sample_B/processings/htseq/sample_B.htseq_count.txt
# 632 GFF lines processed.
# 18763 SAM alignment pairs processed.
# echo "No reads in samples/sample_B/processings/preprocess/trimmomatic/readsB_1.fq.P.qtrim.gz" > samples/sample_B/processings/preprocess/fastqc_stats/readsB_1.fq.P.qtrim_fastqc.html && fastqc samples/sample_B/processings/preprocess/trimmomatic/readsB_1.fq.P.qtrim.gz -o samples/sample_B/processings/preprocess/fastqc_stats > samples/sample_B/processings/preprocess/fastqc_stats/readsB_1.fq.P.qtrim_fastqc.log 2> samples/sample_B/processings/preprocess/fastqc_stats/readsB_1.fq.P.qtrim_fastqc.err
# echo "No reads in samples/sample_B/processings/preprocess/trimmomatic/readsB_1.fq.U.qtrim.gz" > samples/sample_B/processings/preprocess/fastqc_stats/readsB_1.fq.U.qtrim_fastqc.html && fastqc samples/sample_B/processings/preprocess/trimmomatic/readsB_1.fq.U.qtrim.gz -o samples/sample_B/processings/preprocess/fastqc_stats > samples/sample_B/processings/preprocess/fastqc_stats/readsB_1.fq.U.qtrim_fastqc.log 2> samples/sample_B/processings/preprocess/fastqc_stats/readsB_1.fq.U.qtrim_fastqc.err
# echo "No reads in samples/sample_B/processings/preprocess/trimmomatic/readsB_2.fq.P.qtrim.gz" > samples/sample_B/processings/preprocess/fastqc_stats/readsB_2.fq.P.qtrim_fastqc.html && fastqc samples/sample_B/processings/preprocess/trimmomatic/readsB_2.fq.P.qtrim.gz -o samples/sample_B/processings/preprocess/fastqc_stats > samples/sample_B/processings/preprocess/fastqc_stats/readsB_2.fq.P.qtrim_fastqc.log 2> samples/sample_B/processings/preprocess/fastqc_stats/readsB_2.fq.P.qtrim_fastqc.err
# echo "No reads in samples/sample_B/processings/preprocess/trimmomatic/readsB_2.fq.U.qtrim.gz" > samples/sample_B/processings/preprocess/fastqc_stats/readsB_2.fq.U.qtrim_fastqc.html && fastqc samples/sample_B/processings/preprocess/trimmomatic/readsB_2.fq.U.qtrim.gz -o samples/sample_B/processings/preprocess/fastqc_stats > samples/sample_B/processings/preprocess/fastqc_stats/readsB_2.fq.U.qtrim_fastqc.log 2> samples/sample_B/processings/preprocess/fastqc_stats/readsB_2.fq.U.qtrim_fastqc.err
# echo "No reads in /headless/CirComPara/test_circompara/reads/readsB_1.fastq.gz" > samples/sample_B/read_statistics/fastqc_stats/readsB_1_fastqc.html && fastqc /headless/CirComPara/test_circompara/reads/readsB_1.fastq.gz -o samples/sample_B/read_statistics/fastqc_stats > samples/sample_B/read_statistics/fastqc_stats/readsB_1.fastq_fastqc.log 2> samples/sample_B/read_statistics/fastqc_stats/readsB_1.fastq_fastqc.err
# echo "No reads in /headless/CirComPara/test_circompara/reads/readsB_2.fastq.gz" > samples/sample_B/read_statistics/fastqc_stats/readsB_2_fastqc.html && fastqc /headless/CirComPara/test_circompara/reads/readsB_2.fastq.gz -o samples/sample_B/read_statistics/fastqc_stats > samples/sample_B/read_statistics/fastqc_stats/readsB_2.fastq_fastqc.log 2> samples/sample_B/read_statistics/fastqc_stats/readsB_2.fastq_fastqc.err
# gffread -w transcript_sequences/transcripts.fa -g /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.fa /headless/CirComPara/test_circompara/annotation/CFLAR_HIPK3.gtf
# scons: done building targets.

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Results:

# %% [markdown]
# - Viewing output files after running CirComPara:

# %%
from IPython.display import FileLinks, FileLink

FileLinks('/headless/CirComPara/test_circompara/analysis/')
# Out:
# /headless/CirComPara/test_circompara/analysis/
#   .sconsign.dblite
#   meta.csv
#   vars.py
# /headless/CirComPara/test_circompara/analysis/circRNA_collection/
#   circrna_maps_counts.txt
#   CIRCexplorer_compared.csv
#   testrealign_compared.csv
#   find_circ_compared.csv
#   ciri_compared.csv
#   circrnas.gtf
#   combined_circrnas.gtf.gz
# /headless/CirComPara/test_circompara/analysis/circrna_analyze/
#   sample_A_circrna_norm_expression.csv
#   circRNAs_analysis.html
#   circRNA_gene_expression_correlation.csv
#   circRNAs_per_gene.csv
#   sample_B_circrna_norm_expression.csv
#   circRNA_expression_per_sample.csv
#   methods_shared_circRNA_counts.csv
# /headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/
#   show_circrnas_shared-1.svg
#   corr_density_plot-1.png
#   plot_circ_gene_expr-1.svg
#   show_circrnas_per_method-1.svg
#   correlations_box-1.svg
#   plot_circrnas_per_gene-1.svg
#   cumulative_expression_box-1.png
#   corr_density_plot-1.svg
#   plot_gene_expressed_by_sample-1.svg
#   show_circrnas_per_method-1.png
#   plot_circrnas_per_gene-1.png
#   correlations_box-1.png
#   plot_circrnas_2reads_2methods_sample-1.png
#   plot_circ_gene_expr-1.png
#   plot_circrnas_2reads_2methods_sample-1.svg
#   cumulative_expression_box-1.svg
#   show_circrnas_shared-1.png
#   plot_gene_expressed_by_sample-1.png
# /headless/CirComPara/test_circompara/analysis/cuffdiff/
#   tss_groups.fpkm_tracking
#   isoforms.read_group_tracking
#   genes.read_group_tracking
#   tss_groups.read_group_tracking
#   isoforms.count_tracking
#   genes.count_tracking
#   cds.count_tracking
#   read_groups.info
#   run.info
#   cds.fpkm_tracking
#   genes.fpkm_tracking
#   tss_groups.count_tracking
#   isoforms.fpkm_tracking
#   cds.read_group_tracking
# /headless/CirComPara/test_circompara/analysis/cuffquant/sample_A_hisat2/
#   abundances.cxb
# /headless/CirComPara/test_circompara/analysis/cuffquant/sample_B_hisat2/
#   abundances.cxb
# /headless/CirComPara/test_circompara/analysis/junk2_dbs/
#   CFLAR_HIPK3.genePred.wgn
#   genePred.transcripts.info
#   CFLAR_HIPK3.genePred
# /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/bowtie2/
#   CFLAR_HIPK3.2.bt2
#   CFLAR_HIPK3.rev.1.bt2
#   CFLAR_HIPK3.4.bt2
#   CFLAR_HIPK3.3.bt2
#   CFLAR_HIPK3.1.bt2
#   CFLAR_HIPK3.rev.2.bt2
# /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/bwa/
#   CFLAR_HIPK3.pac
#   CFLAR_HIPK3.bwt
#   CFLAR_HIPK3.amb
#   CFLAR_HIPK3.sa
#   CFLAR_HIPK3.ann
# /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/hisat2/
#   CFLAR_HIPK3.7.ht2
#   CFLAR_HIPK3.6.ht2
#   CFLAR_HIPK3.5.ht2
#   CFLAR_HIPK3.3.ht2
#   CFLAR_HIPK3.1.ht2
#   CFLAR_HIPK3.8.ht2
#   CFLAR_HIPK3.2.ht2
#   CFLAR_HIPK3.4.ht2
# /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/segemehl/
#   CFLAR_HIPK3.idx
# /headless/CirComPara/test_circompara/analysis/junk2_dbs/indexes/star/CFLAR_HIPK3/
#   genomeParameters.txt
#   Genome
#   chrLength.txt
#   SA
#   chrName.txt
#   chrStart.txt
#   chrNameLength.txt
#   SAindex
#   Log.out
# /headless/CirComPara/test_circompara/analysis/read_stats_collect/
#   read_stats_collect.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/CIRCexplorer/
#   fusion_junction.txt
#   CIRCexplorer_circ.txt
#   CIRCExplorer_mapped_reads_count.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/CIRCexplorer/star_out/
#   SJ.out.tab
#   Log.progress.out
#   Aligned.sortedByCoord.out.bam
#   Chimeric.out.sam
#   Log.out
#   Chimeric.out.junction
#   Log.final.out
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/CIRCexplorer/star_out/_STARgenome/
#   exonGeTrInfo.tab
#   transcriptInfo.tab
#   sjdbList.fromGTF.out.tab
#   exonInfo.tab
#   sjdbList.out.tab
#   geneInfo.tab
#   sjdbInfo.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/ciri_out/
#   processings_ciri.out
#   CIRI_mapped_reads_count.txt
#   processings_ciri.out.log
#   processings_bwa.sam.gz
#   CIRIerror.log
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/find_circ_out/
#   processings_bt2.bam
#   sites.bed
#   bt2_firstpass.log
#   find_circ.log
#   find_circ_mapped_reads_count.txt
#   circ_candidates.bed
#   sites.reads
#   bt2_secondpass.log
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/segemehl/
#   processings.bam
#   processings_unmatched.fastq.gz
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/circRNAs/testrealign/
#   segemehl_mapped_reads_count.txt
#   processings_sorted.sam.gz
#   splicesites.bed
#   transrealigned.bed
#   processings_circular.junction.stats.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/cufflinks/
#   skipped.gtf
#   genes.fpkm_tracking
#   transcripts.gtf
#   isoforms.fpkm_tracking
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/hisat2_out/
#   sample_A_hisat2.bam
#   sample_A_hisat2.log
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/htseq/
#   sample_A.htseq_count.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/preprocess/fastqc_stats/
#   readsA_2.fq.P.qtrim_fastqc.zip
#   readsA_1.fq.P.qtrim_fastqc.err
#   readsA_1.fq.U.qtrim_fastqc.err
#   readsA_1.fq.P.qtrim_fastqc.log
#   readsA_1.fq.P.qtrim_fastqc.html
#   readsA_2.fq.P.qtrim_fastqc.log
#   readsA_2.fq.P.qtrim_fastqc.err
#   readsA_2.fq.U.qtrim_fastqc.zip
#   readsA_1.fq.U.qtrim_fastqc.log
#   readsA_1.fq.U.qtrim_fastqc.html
#   readsA_2.fq.U.qtrim_fastqc.log
#   readsA_2.fq.U.qtrim_fastqc.html
#   readsA_1.fq.U.qtrim_fastqc.zip
#   readsA_2.fq.U.qtrim_fastqc.err
#   readsA_2.fq.P.qtrim_fastqc.html
#   readsA_1.fq.P.qtrim_fastqc.zip
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/preprocess/trimmomatic/
#   readsA_2.fq.P.qtrim.gz
#   readsA_1.fq.P.qtrim.gz
#   readsA_2.fq.U.qtrim.gz
#   trimmomatic.log
#   readsA_1.fq.U.qtrim.gz
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/processings/unmapped_reads/
#   unmapped_1.fastq.gz
#   singleton.fastq.gz
#   unmapped_2.fastq.gz
# /headless/CirComPara/test_circompara/analysis/samples/sample_A/read_statistics/fastqc_stats/
#   readsA_2.fastq_fastqc.err
#   readsA_2_fastqc.zip
#   readsA_1_fastqc.zip
#   readsA_1_fastqc.html
#   readsA_1.fastq_fastqc.err
#   readsA_2_fastqc.html
#   readsA_1.fastq_fastqc.log
#   readsA_2.fastq_fastqc.log
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/CIRCexplorer/
#   fusion_junction.txt
#   CIRCexplorer_circ.txt
#   CIRCExplorer_mapped_reads_count.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/CIRCexplorer/star_out/
#   SJ.out.tab
#   Log.progress.out
#   Aligned.sortedByCoord.out.bam
#   Chimeric.out.sam
#   Log.out
#   Chimeric.out.junction
#   Log.final.out
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/CIRCexplorer/star_out/_STARgenome/
#   exonGeTrInfo.tab
#   transcriptInfo.tab
#   sjdbList.fromGTF.out.tab
#   exonInfo.tab
#   sjdbList.out.tab
#   geneInfo.tab
#   sjdbInfo.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/ciri_out/
#   processings_ciri.out
#   CIRI_mapped_reads_count.txt
#   processings_ciri.out.log
#   processings_bwa.sam.gz
#   CIRIerror.log
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/find_circ_out/
#   processings_bt2.bam
#   sites.bed
#   bt2_firstpass.log
#   find_circ.log
#   find_circ_mapped_reads_count.txt
#   circ_candidates.bed
#   sites.reads
#   bt2_secondpass.log
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/segemehl/
#   processings.bam
#   processings_unmatched.fastq.gz
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/circRNAs/testrealign/
#   segemehl_mapped_reads_count.txt
#   processings_sorted.sam.gz
#   splicesites.bed
#   transrealigned.bed
#   processings_circular.junction.stats.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/cufflinks/
#   skipped.gtf
#   genes.fpkm_tracking
#   transcripts.gtf
#   isoforms.fpkm_tracking
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/hisat2_out/
#   sample_B_hisat2.bam
#   sample_B_hisat2.log
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/htseq/
#   sample_B.htseq_count.txt
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/preprocess/fastqc_stats/
#   readsB_1.fq.U.qtrim_fastqc.log
#   readsB_1.fq.U.qtrim_fastqc.err
#   readsB_2.fq.U.qtrim_fastqc.log
#   readsB_2.fq.P.qtrim_fastqc.err
#   readsB_1.fq.U.qtrim_fastqc.html
#   readsB_1.fq.P.qtrim_fastqc.zip
#   readsB_1.fq.U.qtrim_fastqc.zip
#   readsB_2.fq.P.qtrim_fastqc.zip
#   readsB_2.fq.U.qtrim_fastqc.zip
#   readsB_2.fq.U.qtrim_fastqc.html
#   readsB_1.fq.P.qtrim_fastqc.err
#   readsB_2.fq.U.qtrim_fastqc.err
#   readsB_1.fq.P.qtrim_fastqc.html
#   readsB_2.fq.P.qtrim_fastqc.html
#   readsB_1.fq.P.qtrim_fastqc.log
#   readsB_2.fq.P.qtrim_fastqc.log
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/preprocess/trimmomatic/
#   readsB_1.fq.P.qtrim.gz
#   readsB_2.fq.P.qtrim.gz
#   readsB_1.fq.U.qtrim.gz
#   trimmomatic.log
#   readsB_2.fq.U.qtrim.gz
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/processings/unmapped_reads/
#   unmapped_1.fastq.gz
#   singleton.fastq.gz
#   unmapped_2.fastq.gz
# /headless/CirComPara/test_circompara/analysis/samples/sample_B/read_statistics/fastqc_stats/
#   readsB_2.fastq_fastqc.err
#   readsB_1.fastq_fastqc.log
#   readsB_1.fastq_fastqc.err
#   readsB_2_fastqc.zip
#   readsB_1_fastqc.html
#   readsB_1_fastqc.zip
#   readsB_2.fastq_fastqc.log
#   readsB_2_fastqc.html
# /headless/CirComPara/test_circompara/analysis/transcript_sequences/
#   transcripts.fa

# %% [markdown]
# - Viewing graphic files after running CirComPara:

# %%
from IPython.display import Image
Image("/headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/corr_density_plot-1.png")

# %%
from IPython.display import Image
Image("/headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/cumulative_expression_box-1.png")

# %%
from IPython.display import Image
Image("/headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/show_circrnas_per_method-1.png")

# %%
from IPython.display import Image
Image("/headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/plot_circrnas_per_gene-1.png")

# %%
from IPython.display import Image
Image("/headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/correlations_box-1.png")

# %%
from IPython.display import Image
Image("/headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/plot_circrnas_2reads_2methods_sample-1.png")

# %%
from IPython.display import Image
Image("/headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/plot_circ_gene_expr-1.png")

# %%
from IPython.display import Image
Image("/headless/CirComPara/test_circompara/analysis/circrna_analyze/Figs/plot_gene_expressed_by_sample-1.png")

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **NOTE:** This pipeline is just an example of what you can do with Dugong. I
